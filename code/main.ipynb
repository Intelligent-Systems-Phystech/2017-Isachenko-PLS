# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
rc('text', usetex=True)
# %matplotlib inline
import scipy as sc
from scipy import io
from IPython import display
import time
import os

from sklearn.metrics import mean_squared_error
from sklearn.cross_decomposition import PLSRegression

from nonlinearities import *
from pls import *

np.random.seed(42)
# Out:
# /Users/r-isachenko/opt/anaconda3/lib/python3.7/site-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)

# %%
NONPARAMETRICAL_TRANSROMATIONS = ['linear', 'p2', 'p3', 'p4', 's2', 's3', 's4']


def mse(Y_test, Y_pred):
    return mean_squared_error(Y_test, Y_pred)


def nmse(Y_test, Y_pred):
    return mean_squared_error(Y_test, Y_pred) / baseline(Y_test)


def baseline(Y_test):
     return mse(Y_test, np.tile(Y_test.mean(axis=0), (len(Y_test), 1)))

# %% [markdown]
# ## Electroenergy

# %%
X = sc.io.loadmat('./../data/dataX.mat')['arr']
Y = sc.io.loadmat('./../data/dataY.mat')['arr']
# some daily information (5 weeks)
X = X[:-8, :-35]
Y = Y[8:, :-5]

train_size = 700

X_train, X_test = X[:train_size, :], X[train_size:, :]
Y_train, Y_test = Y[:train_size, :], Y[train_size:, :]

# %%
X_train.shape, Y_train.shape, X_test.shape, Y_test.shape
# Out:
# ((700, 168), (700, 24), (381, 168), (381, 24))

# %%
np.random.seed(42)
pls = PLSNonLinear(n_components=5, x_kind='linear', y_kind='linear')
pls.fit(X_train, Y_train)
Y_pred = pls.predict(X_test)
print(nmse(Y_train, pls.predict(X_train)))
print(nmse(Y_test, Y_pred))
# Out:
# 0.0952924875402
# 0.115484510883

# %%
mse_n_comps = []

for k in np.arange(1, 21):
    pls = PLSNonLinear(n_components=k, x_kind='linear', y_kind='linear')
    pls.fit(X_train, Y_train)
    Y_pred = pls.predict(X_test)
    mse_n_comps.append(nmse(Y_test, Y_pred))
    display.clear_output(wait=True)
    print('Iteration {} is over'.format(k))
    
mse_n_comps = np.array(mse_n_comps)
# Out:
# Iteration 20 is over

# %%
plt.figure(figsize=(6, 3))
plt.plot(np.arange(1, 21), mse_n_comps)
plt.xlabel('Number of PLS components, $l$', fontsize=12)
plt.ylabel('NMSE', fontsize=12)
plt.xticks([0, 5, 10, 15, 20], fontsize=11)
plt.yticks([0.1, 0.2, 0.3], fontsize=11)

plt.tight_layout()
plt.savefig('figs/energy_n_comp.eps', format='eps')
plt.show()

# %%
n_comp = mse_n_comps.argmin() + 1
n_comp
# Out:
# 14

# %%
pls = PLSNonLinear(n_components=n_comp, x_kind='linear', y_kind='linear')
pls.fit(X_train, Y_train)
Y_pred = pls.predict(X_test)

ts_test = Y_test.ravel()
ts_pred = Y_pred.ravel()

# %%
test = ts_test[20:20 + 24 * 7]
pred = ts_pred[20:20 + 24 * 7]

plt.figure(figsize=(10, 5))
plt.plot(test, label='time series', c='blue')
plt.plot(pred, label='prediction', c='orangered')

plt.legend(fontsize=16)
plt.ylim([test.min() - 0.05, test.max() + 0.15])
plt.xlim([0, 168])
plt.xticks([24 * i for i in range(8)], fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Time, h', fontsize=16)
plt.ylabel('Energy consumption', fontsize=16)
plt.tight_layout()
plt.savefig('figs/energy_prediction.eps', format='eps')
plt.show()

# %% [raw]
# results_energy = {}
# BASELINE_ENERGY = baseline(Y_test)
#
# for x_transform in NONPARAMETRICAL_TRANSROMATIONS:
#     for y_transform in NONPARAMETRICAL_TRANSROMATIONS:
#         mse_n_comps = []
#         for n_comp in range(1, 25):
#             pls = PLSNonLinear(n_components=n_comp,
#                                x_kind=x_transform,
#                                y_kind=y_transform)
#             pls.fit(X_train, Y_train)
#             Y_pred = pls.predict(X_test)
#             mse_n_comps.append(mse(Y_test, Y_pred))
#         mse_n_comps = np.array(mse_n_comps)
#         best_mse = mse_n_comps.min()
#         results_energy[x_transform + '-' + y_transform] = mse_n_comps
#         display.clear_output(wait=True)
#         print('-x_transform:', x_transform)
#         print('-y_transform:', y_transform)
#         print('-mse: {:.5f}'.format(best_mse))
#         print('-nmse: {:.5f}'.format(best_mse / BASELINE_ENERGY))

# %% [markdown]
# ## ECoG

# %%
X_train_ecog = sc.io.loadmat('ECoG_X_train.mat')['X_train'].reshape([-1, 32 * 27])
Y_train_ecog = sc.io.loadmat('ECoG_Y_train.mat')['Y_train']

X_test_ecog = sc.io.loadmat('ECoG_X_test.mat')['X_hold_out'].reshape([-1, 32 * 27])
Y_test_ecog = sc.io.loadmat('ECoG_Y_test.mat')['Y_hold_out']

print(X_train_ecog.shape, Y_train_ecog.shape)
print(X_test_ecog.shape, Y_test_ecog.shape)

x_autoreg_step = 18
y_autoreg_step = 10
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/io/matlab/mio.py in _open_file(file_like, appendmat, mode)
#      38     try:
# ---> 39         return open(file_like, mode), True
#      40     except IOError:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ECoG_X_train.mat'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-50c1e8e441e3> in <module>
# ----> 1 X_train_ecog = sc.io.loadmat('ECoG_X_train.mat')['X_train'].reshape([-1, 32 * 27])
#       2 Y_train_ecog = sc.io.loadmat('ECoG_Y_train.mat')['Y_train']
#       3
#       4 X_test_ecog = sc.io.loadmat('ECoG_X_test.mat')['X_hold_out'].reshape([-1, 32 * 27])
#       5 Y_test_ecog = sc.io.loadmat('ECoG_Y_test.mat')['Y_hold_out']
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/io/matlab/mio.py in loadmat(file_name, mdict, appendmat, **kwargs)
#     214     """
#     215     variable_names = kwargs.pop('variable_names', None)
# --> 216     with _open_file_context(file_name, appendmat) as f:
#     217         MR, _ = mat_reader_factory(f, **kwargs)
#     218         matfile_dict = MR.get_variables(variable_names)
#
# ~/opt/anaconda3/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/io/matlab/mio.py in _open_file_context(file_like, appendmat, mode)
#      17 @contextmanager
#      18 def _open_file_context(file_like, appendmat, mode='rb'):
# ---> 19     f, opened = _open_file(file_like, appendmat, mode)
#      20     yield f
#      21     if opened:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/io/matlab/mio.py in _open_file(file_like, appendmat, mode)
#      43             if appendmat and not file_like.endswith('.mat'):
#      44                 file_like += '.mat'
# ---> 45             return open(file_like, mode), True
#      46         else:
#      47             raise IOError('Reader needs file name or open file-like object')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ECoG_X_train.mat'

# %%
sh = X_train_ecog.shape
X_train = np.zeros([sh[0] - x_autoreg_step - y_autoreg_step + 2, x_autoreg_step * sh[1]])
for i in range(len(X_train)):
    X_train[i] = X_train_ecog[i:i + x_autoreg_step].ravel()

sh = Y_train_ecog.shape
Y_train = np.zeros([sh[0] - x_autoreg_step - y_autoreg_step + 2, y_autoreg_step * sh[1]])
for i in range(len(Y_train)):
    Y_train[i] = Y_train_ecog[i + x_autoreg_step - 1:i + y_autoreg_step + x_autoreg_step - 1].ravel()

print(X_train.shape, Y_train.shape)

sh = X_test_ecog.shape
X_test = np.zeros([sh[0] - x_autoreg_step - y_autoreg_step + 2, x_autoreg_step * sh[1]])
for i in range(len(X_test)):
    X_test[i] = X_test_ecog[i:i + x_autoreg_step].ravel()

sh = Y_test_ecog.shape
Y_test = np.zeros([sh[0] - x_autoreg_step - y_autoreg_step + 2, y_autoreg_step * sh[1]])
for i in range(len(Y_test)):
    Y_test[i] = Y_test_ecog[i + x_autoreg_step - 1:i + y_autoreg_step + x_autoreg_step - 1].ravel()

print(X_test.shape, Y_test.shape)

# %%
pls = PLSNonLinear(n_components=10)
pls.fit(X_train, Y_train)
Y_pred = pls.predict(X_test)
print(mse(Y_test, Y_pred))
print(nmse(Y_test, Y_pred))
# Out:
# 1529.3529759
# 0.815738094129

# %%
mse_n_comps = []

for k in np.arange(1, 21):
    pls = PLSNonLinear(n_components=k, x_kind='linear', y_kind='linear')
    pls.fit(X_train, Y_train)
    Y_pred = pls.predict(X_test)
    mse_n_comps.append(nmse(Y_test, Y_pred))
    display.clear_output(wait=True)
    print('Iteration {} is over'.format(k))
    
mse_n_comps = np.array(mse_n_comps)
# Out:
# Iteration 20 is over

# %%
plt.figure(figsize=(6, 3))
plt.plot(mse_n_comps)
plt.xlabel('Number of PLS components, $l$', fontsize=12)
plt.ylabel('NMSE', fontsize=12)
plt.xticks(fontsize=11)
plt.yticks([0.8, 0.9, 1.], fontsize=11)

plt.tight_layout()
plt.savefig('figs/ecog_n_comp.eps', format='eps')
plt.show()

# %%
n_comp = mse_n_comps.argmin() + 1
n_comp
# Out:
# 16

# %%
pls = PLSNonLinear(n_components=n_comp)
pls.fit(X_train, Y_train)
Y_pred = pls.predict(X_test)

ts_pred = np.zeros([len(Y_test) - y_autoreg_step + 1, 3])
ts_test = np.zeros([len(Y_test) - y_autoreg_step + 1, 3])

for i in range(len(ts_pred)):
    ts_pred[i, 0] = np.mean([Y_pred[i + y_autoreg_step - 1 - k, 3 * k] 
                             for k in range(y_autoreg_step)])
    ts_pred[i, 1] = np.mean([Y_pred[i + y_autoreg_step - 1 - k, 3 * k + 1] 
                             for k in range(y_autoreg_step)])
    ts_pred[i, 2] = np.mean([Y_pred[i + y_autoreg_step - 1 - k, 3 * k + 2] 
                             for k in range(y_autoreg_step)])

ts_test = Y_test[:-y_autoreg_step + 1, -3:]

print(ts_pred.shape, ts_test.shape)
# Out:
# (6055, 3) (6055, 3)

# %%
test = ts_test[:1000]
pred = ts_pred[:1000]

plt.figure(figsize=(10, 6))
plt.plot(test[:, 0], label='$x$-axis true', c='r')
plt.plot(pred[:, 0], label='$x$-axis pred', linestyle='--', c='r')
plt.plot(test[:, 1], label='$y$-axis true', c='g')
plt.plot(pred[:, 1], label='$y$-axis pred', linestyle='--', c='g')
plt.plot(test[:, 2], label='$z$-axis true', c='b')
plt.plot(pred[:, 2], label='$z$-axis pred', linestyle='--', c='b')
lgd = plt.legend(fontsize=16, bbox_to_anchor=(0.17, 0.85, 1., .102), loc=3, borderaxespad=0., ncol=3)
plt.ylim([test.min() - 50, test.max() + 100])
#plt.xlim([0, 144])
plt.yticks(fontsize=16)
plt.xticks(fontsize=16)
plt.ylabel('Wrist coordinates', fontsize=16)
plt.xlabel('Time, ms', fontsize=16)
plt.tight_layout()
plt.savefig('figs/ecog_prediction.eps', format='eps', bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()

# %% [raw]
# results = []
# for x_autoreg_step in range(18, 19, 2):
#     results.append([])
#     for y_autoreg_step in range(12, 13, 2):
#         sh = X_train_ecog.shape
#         X_train = np.zeros([sh[0] - x_autoreg_step - y_autoreg_step + 2, x_autoreg_step * sh[1]])
#         for i in range(len(X_train)):
#             X_train[i] = X_train_ecog[i:i + x_autoreg_step].ravel()
#
#         sh = Y_train_ecog.shape
#         Y_train = np.zeros([sh[0] - x_autoreg_step - y_autoreg_step + 2, y_autoreg_step * sh[1]])
#         for i in range(len(Y_train)):
#             Y_train[i] = Y_train_ecog[i + x_autoreg_step - 1:i + y_autoreg_step + x_autoreg_step - 1].ravel()
#
#         sh = X_test_ecog.shape
#         X_test = np.zeros([sh[0] - x_autoreg_step - y_autoreg_step + 2, x_autoreg_step * sh[1]])
#         for i in range(len(X_test)):
#             X_test[i] = X_test_ecog[i:i + x_autoreg_step].ravel()
#
#         sh = Y_test_ecog.shape
#         Y_test = np.zeros([sh[0] - x_autoreg_step - y_autoreg_step + 2, y_autoreg_step * sh[1]])
#         for i in range(len(Y_test)):
#             Y_test[i] = Y_test_ecog[i + x_autoreg_step - 1:i + y_autoreg_step + x_autoreg_step - 1].ravel()
#
#         mse_n_comps = []
#
#         for n_comp in np.arange(2, 21):
#             pls = PLSNonLinear(n_components=n_comp, x_kind='linear', y_kind='linear')
#             pls.fit(X_train, Y_train)
#             Y_pred = pls.predict(X_test)
#
#             ts_pred = np.zeros([len(Y_test) - y_autoreg_step + 1, 3])
#             ts_test = np.zeros([len(Y_test) - y_autoreg_step + 1, 3])
#
#             for i in range(len(ts_pred)):
#                 ts_pred[i, 0] = np.mean([Y_pred[i + y_autoreg_step - 1 - k, 3 * k]
#                                          for k in range(y_autoreg_step)])
#                 ts_pred[i, 1] = np.mean([Y_pred[i + y_autoreg_step - 1 - k, 3 * k + 1]
#                                          for k in range(y_autoreg_step)])
#                 ts_pred[i, 2] = np.mean([Y_pred[i + y_autoreg_step - 1 - k, 3 * k + 2]
#                                          for k in range(y_autoreg_step)])
#
#             ts_test = Y_test[:-y_autoreg_step + 1, -3:]
#             mse_n_comps.append(nmse(ts_test, ts_pred))
#             display.clear_output(wait=True)
#             print(nmse(ts_test, ts_pred))
#             print('Iteration {} is over'.format(n_comp))
#
#         mse_n_comps = np.array(mse_n_comps)
#         results[-1].append(mse_n_comps)
#
#         plt.figure(figsize=(6, 4))
#         plt.plot(mse_n_comps)
#         plt.xlabel('Number of components')
#         plt.ylabel('MSE')
#         plt.ylim([0.75, 0.95])
#         plt.savefig('figs/x_autoreg_step={}_y_autoreg_step={}.eps'.format(x_autoreg_step,
#                                                                           y_autoreg_step), format='eps')
#         display.clear_output(wait=True)
#         print('x_autoreg_step={}, y_autoreg_step={}, NMSE={:.5f}'.format(x_autoreg_step,
#                                                                          y_autoreg_step,
#                                                                          mse_n_comps[-1]))
# # np.save('results.npy', np.array(results))

# %%
plt.figure(figsize=(6, 3))
plt.plot(np.arange(2, 21), mse_n_comps)
plt.xlabel('Number of PLS components, $l$', fontsize=12)
plt.ylabel('NMSE', fontsize=12)
plt.xticks(fontsize=11)
plt.yticks([0.7, 0.8, 0.9], fontsize=11)
plt.xticks([0, 5, 10, 15, 20], fontsize=11)

plt.tight_layout()
plt.savefig('figs/ecog_n_comp.eps', format='eps')
plt.show()

# %%
n_comp = mse_n_comps.argmin() + 1
n_comp
# Out:
# 17

# %%
n_comp = mse_n_comps.argmin()
print(n_comp, mse_n_comps.min())
# Out:
# 16 0.731378368539

# %%
pls = PLSNonLinear(n_components=17)
pls.fit(X_train, Y_train)
Y_pred = pls.predict(X_test)

ts_pred = np.zeros([len(Y_test) - y_autoreg_step + 1, 3])
ts_test = np.zeros([len(Y_test) - y_autoreg_step + 1, 3])

for i in range(len(ts_pred)):
    ts_pred[i, 0] = np.mean([Y_pred[i + y_autoreg_step - 1 - k, 3 * k] 
                             for k in range(y_autoreg_step)])
    ts_pred[i, 1] = np.mean([Y_pred[i + y_autoreg_step - 1 - k, 3 * k + 1] 
                             for k in range(y_autoreg_step)])
    ts_pred[i, 2] = np.mean([Y_pred[i + y_autoreg_step - 1 - k, 3 * k + 2] 
                             for k in range(y_autoreg_step)])

ts_test = Y_test[:-y_autoreg_step + 1, -3:] 
print(ts_pred.shape, ts_test.shape)
# Out:
# (6052, 3) (6052, 3)

# %%
test = ts_test[:1000]
pred = ts_pred[:1000]

plt.figure(figsize=(10, 6))
plt.plot(test[:, 0], label='$x$-axis true', c='r')
plt.plot(pred[:, 0], label='$x$-axis pred', linestyle='--', c='r')
plt.plot(test[:, 1], label='$y$-axis true', c='g')
plt.plot(pred[:, 1], label='$y$-axis pred', linestyle='--', c='g')
plt.plot(test[:, 2], label='$z$-axis true', c='b')
plt.plot(pred[:, 2], label='$z$-axis pred', linestyle='--', c='b')
lgd = plt.legend(fontsize=16, bbox_to_anchor=(0.17, 0.85, 1., .102), loc=3, borderaxespad=0., ncol=3)
plt.ylim([test.min() - 50, test.max() + 100])
#plt.xlim([0, 144])
plt.yticks(fontsize=16)
plt.xticks(fontsize=16)
plt.ylabel('Wrist coordinates', fontsize=16)
plt.xlabel('Time, ms', fontsize=16)
plt.tight_layout()
plt.savefig('figs/ecog_prediction.eps', format='eps', bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Nonlinear transformations

# %%
def g1(x, a=0., b=1.):
    return np.sign(x) * np.exp(a) * (np.exp(b * np.abs(x)) - 1)


def g2(x, a=0.):
    return np.sign(x) * np.exp(a) * np.sqrt(np.abs(x))


def g3(x, a=0., b=1.):
    return np.sign(x) * np.exp(a) * (np.exp(b * np.sqrt(np.abs(x))) - 1)


def g4(x, a=0., b=1.):
    return np.sign(x) * np.exp(a) * (np.exp(b * np.abs(x) ** (1./3)) - 1)

# %%
funcs_names = ['$g_1(x)$', '$g_2(x)$', '$g_3(x)$', '$g_4(x)$']
funcs = [g1, g2, g3, g4]
x = np.linspace(start=-3, stop=3, num=100)

plt.figure(figsize=(8, 6))
for f, name in zip(funcs, funcs_names):
    plt.plot(x, f(x), label=name)

plt.legend(fontsize=12)
plt.grid()
plt.xlim([-3., 3.])
plt.ylim([-3., 3.])
plt.show()

# %%
def ginv_1(y, a=0., b=1., tol=1e-9):
    return np.sign(y) * np.log(1 + np.abs(y) * np.exp(-a)) / (b + tol)


def ginv_2(y, a=0.):
    return np.sign(y) * (np.exp(-a) * y) ** 2


def ginv_3(y, a=0., b=1., tol=1e-9):
    return np.sign(y) * (np.log(1 + np.abs(y) * np.exp(-a)) / (b + tol)) ** 2


def ginv_4(y, a=0., b=1., tol=1e-9):
    return np.sign(y) * (np.log(1 + np.abs(y) * np.exp(-a)) / (b + tol)) ** 3

# %%
funcs_names = ['$g^{-1}_1(y)$', '$g^{-1}_2(y)$', '$g^{-1}_3(y)$', '$g^{-1}_4(y)$']
funcs = [ginv_1, ginv_2, ginv_3, ginv_4]
x = np.linspace(start=-5, stop=5, num=100)

plt.figure(figsize=(8, 6))
for f, name in zip(funcs, funcs_names):
    plt.plot(f(x), x, label=name)

plt.legend(fontsize=12)
plt.grid()
plt.xlim([-5., 5.])
plt.ylim([-5., 5.])
plt.show()

# %%
np.sqrt(np.mean((Y_test - Y_test.mean()) ** 2))
# Out:
# 123.88404105191663

# %% [markdown]
# ### Figure

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
rc('text', usetex=True)
# %matplotlib inline
import scipy as sc
from scipy import io
from IPython import display
import time
import os

from mpl_toolkits.mplot3d import Axes3D
rc('text', usetex=True)

X_train_ecog = sc.io.loadmat('./ECoG_data/ECoG_X_train.mat')['X_train']
Y_train_ecog = sc.io.loadmat('./ECoG_data/ECoG_Y_train.mat')['Y_train']

X_test_ecog = sc.io.loadmat('./ECoG_data/ECoG_X_test.mat')['X_hold_out']
Y_test_ecog = sc.io.loadmat('./ECoG_data/ECoG_Y_test.mat')['Y_hold_out']

print(X_train_ecog.shape, Y_train_ecog.shape)
# Out:
# (12801, 32, 27) (12801, 3)

# %%
idx_1, idx_2 = 7000, 7300

FONTSIZE = 26

fig = plt.figure(figsize=(17, 4.5))
ax = plt.subplot(1, 2, 1)

ax.plot(X_train_ecog[idx_1:idx_2, 0, 0], 'royalblue', linewidth=2)
ax.plot(X_train_ecog[idx_1:idx_2, 1, 0] + 130, 'royalblue', linewidth=2)
ax.plot(X_train_ecog[idx_1:idx_2, 2, 0] + 260, 'royalblue', linewidth=2)
ax.plot(X_train_ecog[idx_1:idx_2, 3, 0] + 390, 'royalblue', linewidth=2)

ax.set_yticks([0, 130, 260, 390])
ax.set_yticklabels(['Ch 4', 'Ch 3', 'Ch 2', 'Ch 1'], fontsize=FONTSIZE)

for t in ax.xaxis.get_major_ticks(): t.label.set_fontsize(FONTSIZE)
ax.set_xlabel('Time, ms', fontsize=26)

ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

ax = plt.subplot(1, 2, 2, projection='3d')
ax.grid(False)
ax.w_xaxis.set_pane_color((.95, .95, .95, 0.0))
ax.w_yaxis.set_pane_color((.95, .95, .95, 0.0))
ax.w_zaxis.set_pane_color((.95, .95, .95, 0.0))


ax.set_xticks([100, 150, 200, 250, 300])
ax.set_yticks([230, 280, 330, 380])
ax.set_zticks([50, 100, 150, 200])

for t in ax.zaxis.get_major_ticks(): t.label.set_fontsize(FONTSIZE)
for t in ax.xaxis.get_major_ticks(): t.label.set_fontsize(FONTSIZE)
for t in ax.yaxis.get_major_ticks(): t.label.set_fontsize(FONTSIZE)
    
ax.plot(Y_train_ecog[idx_1:idx_2, 0], 
           Y_train_ecog[idx_1:idx_2, 1], 
           Y_train_ecog[idx_1:idx_2, 2], color='g', linewidth=3)

ax.view_init(30, 40)

from mpl_toolkits.mplot3d import art3d
p = art3d.Line3DCollection(np.array([[
    [ax.get_xlim3d()[0], ax.get_ylim3d()[0], ax.get_zlim3d()[0]],
    [ax.get_xlim3d()[0], ax.get_ylim3d()[0], ax.get_zlim3d()[1]]
]]), linestyles='dashed')
p.set_color('gray')
ax.add_collection3d(p)

p = art3d.Line3DCollection(np.array([[
    [ax.get_xlim3d()[0], ax.get_ylim3d()[0], ax.get_zlim3d()[0]],
    [ax.get_xlim3d()[0], ax.get_ylim3d()[1], ax.get_zlim3d()[0]]
]]), linestyles='dashed')
p.set_color('gray')
ax.add_collection3d(p)

p = art3d.Line3DCollection(np.array([[
    [ax.get_xlim3d()[0], ax.get_ylim3d()[0], ax.get_zlim3d()[0]],
    [ax.get_xlim3d()[1], ax.get_ylim3d()[0], ax.get_zlim3d()[0]]
]]), linestyles='dashed')
p.set_color('gray')
ax.add_collection3d(p)

plt.subplots_adjust(hspace=0)
plt.tight_layout()
plt.savefig('ecog_data.eps', format='eps')
plt.show()

# %%
plt.figure(figsize=(15, 2))
plt.plot(X_train_ecog[2000:2300, 0, 0], 'royalblue', linewidth=4)
plt.axis('off')
plt.tight_layout()
plt.savefig('x_example.png')
plt.show()

plt.figure(figsize=(15, 2))
y = Y_train_ecog[2000:2300] - Y_train_ecog[2000:2300].mean(axis=1, keepdims=True)
y = np.sqrt(y[:, 0] ** 2 + y[:, 1] ** 2 + y[:, 2] ** 2)
plt.plot(y, 'green', linewidth=6)
plt.axis('off')
plt.tight_layout()
plt.savefig('y_example.png')
plt.show()

# %%
plt.figure(figsize=(15, 3))
y = Y_train_ecog[2000:2300] - Y_train_ecog[2000:2300].mean(axis=1, keepdims=True)
y = np.sqrt(y[:, 0] ** 2 + y[:, 1] ** 2 + y[:, 2] ** 2)
plt.plot(y, 'green', linewidth=2)
plt.show()

# %%
idx_1, idx_2 = 2000, 3000

FONTSIZE = 26

T0, T1, T2, T3, T4 = 100, 650, 900, 300, 750
Y_MIN, Y_MAX = 0.0, 850.0
X_MIN, X_MAX = -60.0, 500.0
T_MIN, T_MAX = -30.0, 1100

T_LIMIT_COLOR = 'red'
T_LIMIT_N = 10
T_LIMIT_STYLE = 'dashed'

fig = plt.figure(figsize=(10, 9))


# ====================
ax = plt.subplot(2, 1, 1)

for t in [T0, T1, T2]:
    ax.plot(
        np.ones(T_LIMIT_N) * t, np.linspace(Y_MIN, Y_MAX, T_LIMIT_N), 
        c=T_LIMIT_COLOR, linestyle=T_LIMIT_STYLE, linewidth=1
    )


ax.plot(Y_train_ecog[idx_1:idx_2, 0], 'g', linewidth=1)
ax.plot(Y_train_ecog[idx_1:idx_2, 1] + 110, 'g', linewidth=1)
ax.plot(Y_train_ecog[idx_1:idx_2, 2] + 500, 'g', linewidth=1)

ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

ax.set_ylim([Y_MIN, Y_MAX])
ax.set_xlim([T_MIN, T_MAX])
ax.set_yticks([])
ax.set_xticks([T0, T1, T2])
ax.set_xticklabels(['$t - h$', '$t$', '$t + p$'], fontsize=FONTSIZE)

# ====================
ax = plt.subplot(2, 1, 2)

for t in [T0, T1, T2]:
    ax.plot(
        np.ones(T_LIMIT_N) * t, np.linspace(X_MIN, X_MAX, T_LIMIT_N), 
        c=T_LIMIT_COLOR, linestyle=T_LIMIT_STYLE, linewidth=1
    )


ax.plot(X_train_ecog[idx_1:idx_2, 0, 0], 'royalblue', linewidth=1)
ax.plot(X_train_ecog[idx_1:idx_2, 1, 0] + 130, 'royalblue', linewidth=1)
ax.plot(X_train_ecog[idx_1:idx_2, 2, 0] + 260, 'royalblue', linewidth=1)
ax.plot(X_train_ecog[idx_1:idx_2, 3, 0] + 390, 'royalblue', linewidth=1)

ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

ax.set_ylim([X_MIN, X_MAX])
ax.set_xlim([T_MIN, T_MAX])
ax.set_yticks([])
ax.set_xticks([T0, T1, T2])
ax.set_xticklabels(['$t - h$', '$t$', '$t + p$'], fontsize=FONTSIZE)

# ====================
plt.tight_layout()
plt.savefig('xy_example.png')
plt.show()
